# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("hello World")
# Out:
# hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
x = input("Enter Anthing")
print(x)
# Out:
# hello

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
x = int(input("Enter integer"))

if x<0 : 
    print("Negative number")
elif x==0:
    print("zero")    
else:
    print("Positive numer")
# Out:
# zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = (int(input()))
num2 = (int(input()))
num3 = (int(input()))

if num1>num2 & num1>num3:
    print(num1,"is the greatest.")
elif num2>num1 & num2>num3:
    print(num2,"is the greatest.")
else:
    print(num3,"is the greatest.")
# Out:
# 2 is the greatest.

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num= int(input())
fact = 1
if num < 0:
    print(num,"factorial of -ve number is not possiable")
elif num == 0:
    print("Factorial of 0 is 1")
else:
    for i in range(1, num+1):
        fact *= i
    print(f"The factorial of {num} is {fact}")
# Out:
# The factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here``

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Hello"
str2="Moto"
str3=str1+" "+(str2)
print(str3)
# Out:
# Hello Moto

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
val = input()

if val.isdigit():
    print("type is: int")
elif val.replace(".","",1).isdigit():
    print("Type is: float")
elif val.lower() in ["true", "false"]:
    print("Type is: boolean")
else:
    print("Type is: string")
# Out:
# type is: int

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
val1 = int(input())
val2 = int(input())

add = val1+val2
sub = val1-val2
div = val1*val2
mult = val1/val2
mod = val1%val2

print(add);print(sub);print(mult);print(div);print(mod)
# Out:
# 30
# -10
# 0.5
# 200
# 10

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
x1 = int(input())
x2 = int(input())

if x1>x2:
    print(f"{x1} is greater than {x2}")
elif x1==x2:
     print(f"{x1} is equal to {x2}")
elif x1<x2:
      print(f"{x1} is less than   {x2}")
else:
      print(f"{x1} is not equal to {x2}")
# Out:
# 12 is less than   13

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
import math
val = int(input())
sq_no = val**2
print("The square of {val} is", sq_no,"\n")
sqrt = math.sqrt(val)
print("The sq root of {val} is", sqrt)
# Out:
# The square of {val} is 16
#
# The sq root of {val} is 2.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
y = int(input())

if y % 2 ==0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = int(input())

sum = n*((n+1)//2)
print(f"sum of {n} number is :", sum)
# Out:
# sum of 5 number is : 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input())

if (year % 4==0 and year%100 !=0) or (year%400==0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 2022 is not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
line = input()
rev = line[::-1]
if line != rev:
    print(f"Original string: {line}, Reverse string:{rev}")
if line == rev:
    print("string is palindrome ")
# Out:
# Original string: rahul, Reverse string:luhar

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
line = input()
rev = line[::-1]
if line != rev:
    print(f"Original string: {line}, Reverse string:{rev}")
if line == rev:
    print("string is palindrome ")

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
number = list(map(int,input().split()))
asc = sorted(number)
dec = sorted(number, reverse=True)

print(f"Input values:{number} Ascending Number:{asc}")
print(f"Input values:{number} Ascending Number:{dec}")
# Out:
# Input values:[5, 2, 9, 1, 7] Ascending Number:[1, 2, 5, 7, 9]
# Input values:[5, 2, 9, 1, 7] Ascending Number:[9, 7, 5, 2, 1]
